# %%
import os, sys
sys.path.append(os.path.abspath(".."))

from src.data_loader import load_unified_data, load_reference_codes
from src.schema_validation import validate_schema
from src.data_enrichment import add_enrichment_records

df = load_unified_data()
refs = load_reference_codes()

validate_schema(df)

print(df["record_type"].value_counts())
print(df["pillar"].value_counts())
print(df["confidence"].value_counts())

df_enriched = add_enrichment_records(df)
import os

# Ensure the processed directory exists



df_enriched.to_csv(
    "../data/processed/ethiopia_fi_enriched.csv",
    index=False
)
# Out:
# ✅ Schema validation passed. All required columns are present.
# record_type
# observation    30
# event          10
# target          3
# Name: count, dtype: int64
# pillar
# ACCESS           16
# USAGE            11
# GENDER            5
# AFFORDABILITY     1
# Name: count, dtype: int64
# confidence
# high      40
# medium     3
# Name: count, dtype: int64
